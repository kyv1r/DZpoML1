# %% [markdown]
# <a href="https://colab.research.google.com/github/kyv1r/DZpoML1/blob/main/lab1/%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задание по практике 1

# %% [markdown]
# ##Загрузка датасета
# В файле classification datasets расположены ссылки на датасеты. Выберите один в соответствии со своим вариантом, скачайте и прочитайте файл
#
# **Не забудьте загрузить нужные библиотеки**
#
# Например: pip3 install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/ca_offenses_by_agency.csv")
df[:5]
# Out:
#   State/Tribal/Other                              Agency Unit/Office  \
# 0     State Agencies          Atascadero State Hospital4         NaN
# 1     State Agencies              California State Fair4         NaN
# 2     State Agencies             Coalinga State Hospital         NaN
# 3     State Agencies  Department of Parks and Recreation     Angeles
# 4     State Agencies  Department of Parks and Recreation    Bay Area
#
#    Violent crime  Murder and nonnegligent manslaughter  \
# 0          321.0                                   0.0
# 1           12.0                                   0.0
# 2          149.0                                   0.0
# 3            2.0                                   0.0
# 4            0.0                                   0.0
#
#    Rape (revised definition)  Rape (legacy definition)  Robbery  \
# 0                        0.0                       NaN      0.0
# 1                        0.0                       NaN      0.0
# 2                        0.0                       NaN      0.0
# 3                        0.0                       NaN      1.0
# 4                        0.0                       NaN      0.0
#
#    Aggravated assault Property crime  Burglary Larceny-theft  \
# 0               321.0              4       0.0             2
# 1                12.0             79      21.0            56
# 2               149.0              3       1.0             2
# 3                 1.0             26       8.0            18
# 4                 0.0              1       0.0             0
#
#   Motor vehicle theft  Arson
# 0                   2    0.0
# 1                   2    1.0
# 2                   0    0.0
# 3                   0    0.0
# 4                   1    0.0

# %%
# фикс
from numpy import nan

def convert_to_float(df, column_name):
    # Convert the column to string, replace non-numeric values and NaN with empty strings, then convert to float
    df[column_name] = df[column_name].astype(str).str.replace('[^0-9.]', '', regex=True).replace('', nan).astype(float)
    return df[column_name]

# Example for replace the column dtype
df['Violent crime'] = convert_to_float(df, 'Violent crime')
df['Motor vehicle theft'] = convert_to_float(df, 'Motor vehicle theft')
df['Motor vehicle theft']
# Out:
# 0      2.0
# 1      2.0
# 2      0.0
# 3      0.0
# 4      1.0
#       ...
# 228    NaN
# 229    NaN
# 230    NaN
# 231    NaN
# 232    NaN
# Name: Motor vehicle theft, Length: 233, dtype: float64

# %% [markdown]
# ##Первое знакомство с датасетом
# В следующих ячейках выведите:
#
#
# 1.   Колонки датасета
# 2.   Первые 5 значений
# 3.   Последние 5 значений
# 4.   Статистику по числовым колонкам

# %%
#Колонки
df.columns
# Out:
# Index(['State/Tribal/Other', 'Agency', 'Unit/Office', 'Violent crime',
#        'Murder and nonnegligent manslaughter', 'Rape (revised definition)',
#        'Rape (legacy definition)', 'Robbery', 'Aggravated assault',
#        'Property crime', 'Burglary', 'Larceny-theft', 'Motor vehicle theft',
#        'Arson'],
#       dtype='object')

# %%
#Первые 5 значений
df.head()
# Out:
#   State/Tribal/Other                              Agency Unit/Office  \
# 0     State Agencies          Atascadero State Hospital4         NaN
# 1     State Agencies              California State Fair4         NaN
# 2     State Agencies             Coalinga State Hospital         NaN
# 3     State Agencies  Department of Parks and Recreation     Angeles
# 4     State Agencies  Department of Parks and Recreation    Bay Area
#
#    Violent crime  Murder and nonnegligent manslaughter  \
# 0          321.0                                   0.0
# 1           12.0                                   0.0
# 2          149.0                                   0.0
# 3            2.0                                   0.0
# 4            0.0                                   0.0
#
#    Rape (revised definition)  Rape (legacy definition)  Robbery  \
# 0                        0.0                       NaN      0.0
# 1                        0.0                       NaN      0.0
# 2                        0.0                       NaN      0.0
# 3                        0.0                       NaN      1.0
# 4                        0.0                       NaN      0.0
#
#    Aggravated assault Property crime  Burglary Larceny-theft  \
# 0               321.0              4       0.0             2
# 1                12.0             79      21.0            56
# 2               149.0              3       1.0             2
# 3                 1.0             26       8.0            18
# 4                 0.0              1       0.0             0
#
#    Motor vehicle theft  Arson
# 0                  2.0    0.0
# 1                  2.0    1.0
# 2                  0.0    0.0
# 3                  0.0    0.0
# 4                  1.0    0.0

# %%
#Последние 5 значений
df.tail()
# Out:
#     State/Tribal/Other Agency Unit/Office  Violent crime  \
# 228                NaN    NaN         NaN            NaN
# 229                NaN    NaN         NaN            NaN
# 230                NaN    NaN         NaN            NaN
# 231                NaN    NaN         NaN            NaN
# 232                NaN    NaN         NaN            NaN
#
#      Murder and nonnegligent manslaughter  Rape (revised definition)  \
# 228                                   NaN                        NaN
# 229                                   NaN                        NaN
# 230                                   NaN                        NaN
# 231                                   NaN                        NaN
# 232                                   NaN                        NaN
#
#      Rape (legacy definition)  Robbery  Aggravated assault Property crime  \
# 228                       NaN      NaN                 NaN            NaN
# 229                       NaN      NaN                 NaN            NaN
# 230                       NaN      NaN                 NaN            NaN
# 231                       NaN      NaN                 NaN            NaN
# 232                       NaN      NaN                 NaN            NaN
#
#      Burglary Larceny-theft  Motor vehicle theft  Arson
# 228       NaN           NaN                  NaN    NaN
# 229       NaN           NaN                  NaN    NaN
# 230       NaN           NaN                  NaN    NaN
# 231       NaN           NaN                  NaN    NaN
# 232       NaN           NaN                  NaN    NaN

# %%
#Статистику
df.describe()
# Out:
#        Violent crime  Murder and nonnegligent manslaughter  \
# count     169.000000                            169.000000
# mean       15.976331                              0.041420
# std        81.072642                              0.295905
# min         0.000000                              0.000000
# 25%         0.000000                              0.000000
# 50%         0.000000                              0.000000
# 75%         2.000000                              0.000000
# max       803.000000                              3.000000
#
#        Rape (revised definition)  Rape (legacy definition)     Robbery  \
# count                 169.000000                       0.0  169.000000
# mean                    0.201183                       NaN    4.112426
# std                     0.916644                       NaN   31.098238
# min                     0.000000                       NaN    0.000000
# 25%                     0.000000                       NaN    0.000000
# 50%                     0.000000                       NaN    0.000000
# 75%                     0.000000                       NaN    0.000000
# max                     8.000000                       NaN  387.000000
#
#        Aggravated assault    Burglary  Motor vehicle theft       Arson
# count          169.000000  169.000000           169.000000  167.000000
# mean            11.621302    5.668639            74.165680    0.281437
# std             60.029644   20.991983           270.964386    1.140103
# min              0.000000    0.000000             0.000000    0.000000
# 25%              0.000000    0.000000             0.000000    0.000000
# 50%              0.000000    0.000000             1.000000    0.000000
# 75%              2.000000    2.000000            47.000000    0.000000
# max            559.000000  178.000000          3163.000000    8.000000

# %% [markdown]
# **Ответьте на следующие вопросы:**
#
#
# 1.   Какие средние значения в каждой числовой колонке вашего датасета?
# 2.   Минимальные и максимальные значения в каждой числовой колонке вашего датасета

# %% [markdown]
# 1.   **Ответ 1.**
# 2.   **Ответ 2.**

# %%
#Ответ 1.
df.mean()
# Out:
# <ipython-input-9-e1a1a650dddc>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Violent crime                           15.976331
# Murder and nonnegligent manslaughter     0.041420
# Rape (revised definition)                0.201183
# Rape (legacy definition)                      NaN
# Robbery                                  4.112426
# Aggravated assault                      11.621302
# Burglary                                 5.668639
# Motor vehicle theft                     74.165680
# Arson                                    0.281437
# dtype: float64

# %%
#Ответ 2.
df.min()
# Out:
# <ipython-input-10-657ecce50f38>:2: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.min()
# Violent crime                           0.0
# Murder and nonnegligent manslaughter    0.0
# Rape (revised definition)               0.0
# Rape (legacy definition)                NaN
# Robbery                                 0.0
# Aggravated assault                      0.0
# Burglary                                0.0
# Motor vehicle theft                     0.0
# Arson                                   0.0
# dtype: float64

# %%
#Ответ 2.
df.max()
# Out:
# <ipython-input-11-3345acc35954>:2: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.max()
# Violent crime                            803.0
# Murder and nonnegligent manslaughter       3.0
# Rape (revised definition)                  8.0
# Rape (legacy definition)                   NaN
# Robbery                                  387.0
# Aggravated assault                       559.0
# Burglary                                 178.0
# Motor vehicle theft                     3163.0
# Arson                                      8.0
# dtype: float64

# %% [markdown]
# ##Типизация
# Присвойте соответствующим колонкам один из типов (category, float, int)

# %%
df["Murder and nonnegligent manslaughter"] = df["Murder and nonnegligent manslaughter"].astype("category")
df["Burglary"] = df["Burglary"].astype("float64")
df["Rape (revised definition)"] = df["Rape (revised definition)"].astype("float64")
#Вывести типы колонок тут
print(df.dtypes)
# Out:
# State/Tribal/Other                        object
# Agency                                    object
# Unit/Office                               object
# Violent crime                            float64
# Murder and nonnegligent manslaughter    category
# Rape (revised definition)                float64
# Rape (legacy definition)                 float64
# Robbery                                  float64
# Aggravated assault                       float64
# Property crime                            object
# Burglary                                 float64
# Larceny-theft                             object
# Motor vehicle theft                      float64
# Arson                                    float64
# dtype: object

# %% [markdown]
# Какие признаки вы можете выделить в своем датасете (категориальные, числовые и др., **минимум 3 разных**, помните что можно также выделить признаки более точно, например числовые - порядковые, количественные и т.д.)?

# %% [markdown]
# ##Фильтрация
# Офильтруйте 3 колонки вашего датасета и выведите результат

# %%
#Фильтр колонки 1
df[df["Violent crime"] > 100]
# Out:
#     State/Tribal/Other                                      Agency  \
# 0       State Agencies                  Atascadero State Hospital4
# 2       State Agencies                     Coalinga State Hospital
# 90      State Agencies                        Napa State Hospital4
# 91      State Agencies                      Patton State Hospital4
# 106     Other Agencies  Los Angeles Transportation Services Bureau
# 110     Other Agencies        San Francisco Bay Area Rapid Transit
#
#         Unit/Office  Violent crime Murder and nonnegligent manslaughter  \
# 0               NaN          321.0                                  0.0
# 2               NaN          149.0                                  0.0
# 90              NaN          125.0                                  0.0
# 91              NaN          566.0                                  0.0
# 106             NaN          803.0                                  3.0
# 110  Alameda County          135.0                                  1.0
#
#      Rape (revised definition)  Rape (legacy definition)  Robbery  \
# 0                          0.0                       NaN      0.0
# 2                          0.0                       NaN      0.0
# 90                         1.0                       NaN      0.0
# 91                         7.0                       NaN      0.0
# 106                        8.0                       NaN    387.0
# 110                        1.0                       NaN     95.0
#
#      Aggravated assault Property crime  Burglary Larceny-theft  \
# 0                 321.0              4       0.0             2
# 2                 149.0              3       1.0             2
# 90                124.0              7       3.0             4
# 91                559.0              9       4.0             5
# 106               405.0          1,088      11.0           939
# 110                38.0          1,648       3.0         1,294
#
#      Motor vehicle theft  Arson
# 0                    2.0    0.0
# 2                    0.0    0.0
# 90                   0.0    0.0
# 91                   0.0    0.0
# 106                138.0    6.0
# 110                351.0    2.0

# %%
#Фильтр колонки 2
df[df["Rape (revised definition)"] > 1]
# Out:
#     State/Tribal/Other                                      Agency  \
# 91      State Agencies                      Patton State Hospital4
# 102     Other Agencies                     East Bay Regional Parks
# 106     Other Agencies  Los Angeles Transportation Services Bureau
# 108     Other Agencies                   Port of San Diego Harbor4
# 109     Other Agencies      San Bernardino Unified School District
# 111     Other Agencies        San Francisco Bay Area Rapid Transit
#
#              Unit/Office  Violent crime Murder and nonnegligent manslaughter  \
# 91                   NaN          566.0                                  0.0
# 102      Alameda County4            9.0                                  2.0
# 106                  NaN          803.0                                  3.0
# 108                  NaN           87.0                                  1.0
# 109                  NaN           69.0                                  0.0
# 111  Contra Costa County           49.0                                  0.0
#
#      Rape (revised definition)  Rape (legacy definition)  Robbery  \
# 91                         7.0                       NaN      0.0
# 102                        3.0                       NaN      2.0
# 106                        8.0                       NaN    387.0
# 108                        2.0                       NaN     10.0
# 109                        3.0                       NaN     60.0
# 111                        2.0                       NaN     37.0
#
#      Aggravated assault Property crime  Burglary Larceny-theft  \
# 91                559.0              9       4.0             5
# 102                 2.0            195       0.0           188
# 106               405.0          1,088      11.0           939
# 108                74.0            569      53.0           513
# 109                 6.0            362     134.0           201
# 111                10.0            886       0.0           641
#
#      Motor vehicle theft  Arson
# 91                   0.0    0.0
# 102                  7.0    5.0
# 106                138.0    6.0
# 108                  3.0    2.0
# 109                 27.0    3.0
# 111                245.0    7.0

# %%
#Фильтр колонки 3
df[(df["State/Tribal/Other"] == "State Agencies") & (df["Robbery"] > 0)]
# Out:
#    State/Tribal/Other                              Agency  \
# 3      State Agencies  Department of Parks and Recreation
# 50     State Agencies                      Highway Patrol
# 64     State Agencies                      Highway Patrol
# 67     State Agencies                      Highway Patrol
# 76     State Agencies                      Highway Patrol
#
#                Unit/Office  Violent crime  \
# 3                  Angeles            2.0
# 50     Los Angeles County4           48.0
# 64       Riverside County4           19.0
# 67  San Bernardino County4            6.0
# 76          Shasta County4            1.0
#
#    Murder and nonnegligent manslaughter  Rape (revised definition)  \
# 3                                   0.0                        0.0
# 50                                  0.0                        0.0
# 64                                  0.0                        1.0
# 67                                  0.0                        0.0
# 76                                  0.0                        0.0
#
#     Rape (legacy definition)  Robbery  Aggravated assault Property crime  \
# 3                        NaN      1.0                 1.0             26
# 50                       NaN      5.0                43.0            797
# 64                       NaN      1.0                17.0            103
# 67                       NaN      2.0                 4.0             77
# 76                       NaN      1.0                 0.0            239
#
#     Burglary Larceny-theft  Motor vehicle theft  Arson
# 3        8.0            18                  0.0    0.0
# 50       4.0            64                729.0    0.0
# 64       3.0            26                 74.0    0.0
# 67       8.0            21                 48.0    0.0
# 76       0.0            34                205.0    0.0

# %% [markdown]
# ##Группировка
# Сгруппируйте датасет по какому-либо категориальному признаку и выведите среднее значение численных колонок (см. метод mean в pandas)

# %%
#Группировка
df.groupby(["State/Tribal/Other"]).mean()
# Out:
# <ipython-input-16-5931e37dbefa>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["State/Tribal/Other"]).mean()
#                     Violent crime  Rape (revised definition)  \
# State/Tribal/Other
# Other Agencies          19.514706                   0.338235
# State Agencies          14.095745                   0.106383
# Tribal Agencies          6.857143                   0.142857
#
#                     Rape (legacy definition)   Robbery  Aggravated assault  \
# State/Tribal/Other
# Other Agencies                           NaN  9.838235            9.235294
# State Agencies                           NaN  0.106383           13.882979
# Tribal Agencies                          NaN  2.285714            4.428571
#
#                      Burglary  Motor vehicle theft     Arson
# State/Tribal/Other
# Other Agencies      10.279412            12.823529  0.588235
# State Agencies       2.393617           123.755319  0.074468
# Tribal Agencies      4.857143             4.142857  0.000000

# %% [markdown]
# ##Задание для гениев *
# Агрегируйте числовой признак по категориальному признаку с использованием метода **без использования** библиотеки pandas, и вычислите медиану и среднее значение для каждой категории.

# %%
import csv

csv_file_path = "/content/ca_offenses_by_agency.csv"

data_dict = {}

with open(csv_file_path, 'r') as csv_file:
    csv_reader = csv.DictReader(csv_file)

    for row in csv_reader:
        category = row['Agency']
        value = row['Violent crime']

        if category in data_dict:
            data_dict[category].append(value)
        else:

            data_dict[category] = [value]



for category, values in data_dict.items():
    values = [float(val) for val in values]
    median = sorted(values)[len(values) // 2]
    mean = sum(values) / len(values)

    print(f"{category}, Медиана: {median}, Среднее: {mean}")
# Out:
# Atascadero State Hospital4, Медиана: 321.0, Среднее: 321.0
# California State Fair4, Медиана: 12.0, Среднее: 12.0
# Coalinga State Hospital, Медиана: 149.0, Среднее: 149.0
# Department of Parks and Recreation, Медиана: 0.0, Среднее: 0.75
# Fairview Developmental Center4, Медиана: 3.0, Среднее: 3.0
# Highway Patrol, Медиана: 0.0, Среднее: 1.9310344827586208
# Napa State Hospital4, Медиана: 125.0, Среднее: 125.0
# Patton State Hospital4, Медиана: 566.0, Среднее: 566.0
# Porterville Developmental Center4, Медиана: 10.0, Среднее: 10.0
# Sonoma Developmental Center, Медиана: 6.0, Среднее: 6.0
# Coyote Valley Tribal, Медиана: 2.0, Среднее: 2.0
# La Jolla Tribal, Медиана: 5.0, Среднее: 5.0
# Los Coyotes Tribal, Медиана: 7.0, Среднее: 7.0
# Sycuan Tribal, Медиана: 10.0, Среднее: 10.0
# Table Mountain Rancheria, Медиана: 3.0, Среднее: 3.0
# Tule River Tribal, Медиана: 12.0, Среднее: 12.0
# Yurok Tribal, Медиана: 9.0, Среднее: 9.0
# East Bay Municipal Utility4, Медиана: 1.0, Среднее: 1.0
# East Bay Regional Parks, Медиана: 10.0, Среднее: 9.5
# Fontana Unified School District, Медиана: 24.0, Среднее: 24.0
# Los Angeles County Metropolitan Transportation Authority, Медиана: 5.0, Среднее: 5.0
# Los Angeles Transportation Services Bureau, Медиана: 803.0, Среднее: 803.0
# Monterey Peninsula Airport, Медиана: 0.0, Среднее: 0.0
# Port of San Diego Harbor4, Медиана: 87.0, Среднее: 87.0
# San Bernardino Unified School District, Медиана: 69.0, Среднее: 69.0
# San Francisco Bay Area Rapid Transit, Медиана: 49.0, Среднее: 58.5
# Santa Clara Transit District, Медиана: 39.0, Среднее: 39.0
# Shasta County Marshal4, Медиана: 0.0, Среднее: 0.0
# Stockton Unified School District, Медиана: 15.0, Среднее: 15.0
# Twin Rivers Unified School District, Медиана: 24.0, Среднее: 24.0
# Union Pacific Railroad, Медиана: 0.0, Среднее: 0.13725490196078433
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-af0ad10563b1> in <cell line: 25>()
#      24 # Вычислите медиану и среднее значение для каждой категории
#      25 for category, values in data_dict.items():
# ---> 26     values = [float(val) for val in values]
#      27     median = sorted(values)[len(values) // 2]  # Медиана
#      28     mean = sum(values) / len(values)  # Среднее значение
#
# <ipython-input-35-af0ad10563b1> in <listcomp>(.0)
#      24 # Вычислите медиану и среднее значение для каждой категории
#      25 for category, values in data_dict.items():
# ---> 26     values = [float(val) for val in values]
#      27     median = sorted(values)[len(values) // 2]  # Медиана
#      28     mean = sum(values) / len(values)  # Среднее значение
#
# ValueError: could not convert string to float: ''
